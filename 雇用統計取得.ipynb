# %% [markdown]
# <a href="https://colab.research.google.com/github/yamayama3689/finance/blob/main/%E9%9B%87%E7%94%A8%E7%B5%B1%E8%A8%88%E5%8F%96%E5%BE%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import datetime

# %%
# 2018/1/1から現在まで
start = '2015-01-01'
end = datetime.date.today()

# 米非農業部門雇用者数の取得
df_payems = web.DataReader(['PAYEMS'], 'fred', start, end)
df_payems = df_payems.dropna() # 空データ削除

# %%
df_payems.head()
# Out:
#             PAYEMS
# DATE
# 2015-01-01  140568
# 2015-02-01  140827
# 2015-03-01  140923
# 2015-04-01  141196
# 2015-05-01  141538

# %%
# fredAPIを利用して、更新済みのレポートのみを取得する
# !pip install fredapi

# %%
from google.colab import userdata
userdata.get('FRED_API_KEY')
